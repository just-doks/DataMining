# %%
import warnings
warnings.simplefilter('ignore')

# !ls images/images
# Out:
# abomasnow.png		  gothorita.png		  pumpkaboo-average.png
# abra.png		  gourgeist-average.png   pupitar.png
# absol.png		  granbull.png		  purrloin.png
# accelgor.png		  graveler.png		  purugly.png
# aegislash-blade.png	  greninja.png		  pyroar.png
# aerodactyl.png		  grimer.png		  pyukumuku.jpg
# aggron.png		  grotle.png		  quagsire.png
# aipom.png		  groudon.png		  quilava.png
# alakazam.png		  grovyle.png		  quilladin.png
# alomomola.png		  growlithe.png		  qwilfish.png
# altaria.png		  grubbin.jpg		  raichu.png
# amaura.png		  grumpig.png		  raikou.png
# ambipom.png		  gulpin.png		  ralts.png
# amoonguss.png		  gumshoos.jpg		  rampardos.png
# ampharos.png		  gurdurr.png		  rapidash.png
# anorith.png		  guzzlord.jpg		  raticate.png
# araquanid.jpg		  gyarados.png		  rattata.png
# arbok.png		  hakamo-o.jpg		  rayquaza.png
# arcanine.png		  happiny.png		  regice.png
# arceus.png		  hariyama.png		  regigigas.png
# archen.png		  haunter.png		  regirock.png
# archeops.png		  hawlucha.png		  registeel.png
# ariados.png		  haxorus.png		  relicanth.png
# armaldo.png		  heatmor.png		  remoraid.png
# aromatisse.png		  heatran.png		  reshiram.png
# aron.png		  heliolisk.png		  reuniclus.png
# articuno.png		  helioptile.png	  rhydon.png
# audino.png		  heracross.png		  rhyhorn.png
# aurorus.png		  herdier.png		  rhyperior.png
# avalugg.png		  hippopotas.png	  ribombee.jpg
# axew.png		  hippowdon.png		  riolu.png
# azelf.png		  hitmonchan.png	  rockruff.jpg
# azumarill.png		  hitmonlee.png		  roggenrola.png
# azurill.png		  hitmontop.png		  roselia.png
# bagon.png		  honchkrow.png		  roserade.png
# baltoy.png		  honedge.png		  rotom.png
# banette.png		  ho-oh.png		  rowlet.jpg
# barbaracle.png		  hoopa-confined.png	  rufflet.png
# barboach.png		  hoothoot.png		  sableye.png
# basculin-red-striped.png  hoppip.png		  salamence.png
# bastiodon.png		  horsea.png		  salandit.jpg
# bayleef.png		  houndoom.png		  salazzle.jpg
# beartic.png		  houndour.png		  samurott.png
# beautifly.png		  huntail.png		  sandile.png
# beedrill.png		  hydreigon.png		  sandshrew.png
# beheeyem.png		  hypno.png		  sandslash.png
# beldum.png		  igglybuff.png		  sandygast.jpg
# bellossom.png		  illumise.png		  sawk.png
# bellsprout.png		  incineroar.jpg	  sawsbuck.png
# bergmite.png		  infernape.png		  scatterbug.png
# bewear.jpg		  inkay.png		  sceptile.png
# bibarel.png		  ivysaur.png		  scizor.png
# bidoof.png		  jangmo-o.jpg		  scolipede.png
# binacle.png		  jellicent.png		  scrafty.png
# bisharp.png		  jigglypuff.png	  scraggy.png
# blacephalon.jpg		  jirachi.png		  scyther.png
# blastoise.png		  jolteon.png		  seadra.png
# blaziken.png		  joltik.png		  seaking.png
# blissey.png		  jumpluff.png		  sealeo.png
# blitzle.png		  jynx.png		  seedot.png
# boldore.png		  kabuto.png		  seel.png
# bonsly.png		  kabutops.png		  seismitoad.png
# bouffalant.png		  kadabra.png		  sentret.png
# bounsweet.jpg		  kakuna.png		  serperior.png
# braixen.png		  kangaskhan.png	  servine.png
# braviary.png		  karrablast.png	  seviper.png
# breloom.png		  kartana.jpg		  sewaddle.png
# brionne.jpg		  kecleon.png		  sharpedo.png
# bronzong.png		  keldeo-ordinary.png	  shaymin-land.png
# bronzor.png		  kingdra.png		  shedinja.png
# bruxish.jpg		  kingler.png		  shelgon.png
# budew.png		  kirlia.png		  shellder.png
# buizel.png		  klang.png		  shellos.png
# bulbasaur.png		  klefki.png		  shelmet.png
# buneary.png		  klinklang.png		  shieldon.png
# bunnelby.png		  klink.png		  shiftry.png
# burmy.png		  koffing.png		  shiinotic.jpg
# butterfree.png		  komala.jpg		  shinx.png
# buzzwole.jpg		  kommo-o.jpg		  shroomish.png
# cacnea.png		  krabby.png		  shuckle.png
# cacturne.png		  kricketot.png		  shuppet.png
# camerupt.png		  kricketune.png	  sigilyph.png
# carbink.png		  krokorok.png		  silcoon.png
# carnivine.png		  krookodile.png	  silvally.jpg
# carracosta.png		  kyogre.png		  simipour.png
# carvanha.png		  kyurem.png		  simisage.png
# cascoon.png		  lairon.png		  simisear.png
# castform.png		  lampent.png		  skarmory.png
# caterpie.png		  landorus-incarnate.png  skiddo.png
# celebi.png		  lanturn.png		  skiploom.png
# celesteela.jpg		  lapras.png		  skitty.png
# chandelure.png		  larvesta.png		  skorupi.png
# chansey.png		  larvitar.png		  skrelp.png
# charizard.png		  latias.png		  skuntank.png
# charjabug.jpg		  latios.png		  slaking.png
# charmander.png		  leafeon.png		  slakoth.png
# charmeleon.png		  leavanny.png		  sliggoo.png
# chatot.png		  ledian.png		  slowbro.png
# cherrim.png		  ledyba.png		  slowking.png
# cherubi.png		  lickilicky.png	  slowpoke.png
# chesnaught.png		  lickitung.png		  slugma.png
# chespin.png		  liepard.png		  slurpuff.png
# chikorita.png		  lileep.png		  smeargle.png
# chimchar.png		  lilligant.png		  smoochum.png
# chimecho.png		  lillipup.png		  sneasel.png
# chinchou.png		  linoone.png		  snivy.png
# chingling.png		  litleo.png		  snorlax.png
# cinccino.png		  litten.jpg		  snorunt.png
# clamperl.png		  litwick.png		  snover.png
# clauncher.png		  lombre.png		  snubbull.png
# clawitzer.png		  lopunny.png		  solgaleo.jpg
# claydol.png		  lotad.png		  solosis.png
# clefable.png		  loudred.png		  solrock.png
# clefairy.png		  lucario.png		  spearow.png
# cleffa.png		  ludicolo.png		  spewpa.png
# cloyster.png		  lugia.png		  spheal.png
# cobalion.png		  lumineon.png		  spinarak.png
# cofagrigus.png		  lunala.jpg		  spinda.png
# combee.png		  lunatone.png		  spiritomb.png
# combusken.png		  lurantis.jpg		  spoink.png
# comfey.jpg		  luvdisc.png		  spritzee.png
# conkeldurr.png		  luxio.png		  squirtle.png
# corphish.png		  luxray.png		  stakataka.jpg
# corsola.png		  lycanroc-midday.jpg	  stantler.png
# cosmoem.jpg		  machamp.png		  staraptor.png
# cosmog.jpg		  machoke.png		  staravia.png
# cottonee.png		  machop.png		  starly.png
# crabominable.jpg	  magby.png		  starmie.png
# crabrawler.jpg		  magcargo.png		  staryu.png
# cradily.png		  magearna.jpg		  steelix.png
# cranidos.png		  magikarp.png		  steenee.jpg
# crawdaunt.png		  magmar.png		  stoutland.png
# cresselia.png		  magmortar.png		  stufful.jpg
# croagunk.png		  magnemite.png		  stunfisk.png
# crobat.png		  magneton.png		  stunky.png
# croconaw.png		  magnezone.png		  sudowoodo.png
# crustle.png		  makuhita.png		  suicune.png
# cryogonal.png		  malamar.png		  sunflora.png
# cubchoo.png		  mamoswine.png		  sunkern.png
# cubone.png		  manaphy.png		  surskit.png
# cutiefly.jpg		  mandibuzz.png		  swablu.png
# cyndaquil.png		  manectric.png		  swadloon.png
# darkrai.png		  mankey.png		  swalot.png
# darmanitan-standard.png   mantine.png		  swampert.png
# dartrix.jpg		  mantyke.png		  swanna.png
# darumaka.png		  maractus.png		  swellow.png
# decidueye.jpg		  mareanie.jpg		  swinub.png
# dedenne.png		  mareep.png		  swirlix.png
# deerling.png		  marill.png		  swoobat.png
# deino.png		  marowak.png		  sylveon.png
# delcatty.png		  marshadow.jpg		  taillow.png
# delibird.png		  marshtomp.png		  talonflame.png
# delphox.png		  masquerain.png	  tangela.png
# deoxys-normal.png	  mawile.png		  tangrowth.png
# dewgong.png		  medicham.png		  tapu-bulu.jpg
# dewott.png		  meditite.png		  tapu-fini.jpg
# dewpider.jpg		  meganium.png		  tapu-koko.jpg
# dhelmise.jpg		  melmetal.jpg		  tapu-lele.jpg
# dialga.png		  meloetta-aria.png	  tauros.png
# diancie.png		  meltan.jpg		  teddiursa.png
# diggersby.png		  meowstic-male.png	  tentacool.png
# diglett.png		  meowth.png		  tentacruel.png
# ditto.png		  mesprit.png		  tepig.png
# dodrio.png		  metagross.png		  terrakion.png
# doduo.png		  metang.png		  throh.png
# donphan.png		  metapod.png		  thundurus-incarnate.png
# doublade.png		  mew.png		  timburr.png
# dragalge.png		  mewtwo.png		  tirtouga.png
# dragonair.png		  mienfoo.png		  togedemaru.jpg
# dragonite.png		  mienshao.png		  togekiss.png
# drampa.jpg		  mightyena.png		  togepi.png
# drapion.png		  milotic.png		  togetic.png
# dratini.png		  miltank.png		  torchic.png
# drifblim.png		  mime-jr.png		  torkoal.png
# drifloon.png		  mimikyu.jpg		  tornadus-incarnate.png
# drilbur.png		  minccino.png		  torracat.jpg
# drowzee.png		  minior-meteor.jpg	  torterra.png
# druddigon.png		  minun.png		  totodile.png
# ducklett.png		  misdreavus.png	  toucannon.jpg
# dugtrio.png		  mismagius.png		  toxapex.jpg
# dunsparce.png		  moltres.png		  toxicroak.png
# duosion.png		  monferno.png		  tranquill.png
# durant.png		  morelull.jpg		  trapinch.png
# dusclops.png		  mothim.png		  treecko.png
# dusknoir.png		  mr-mime.png		  trevenant.png
# duskull.png		  mudbray.jpg		  tropius.png
# dustox.png		  mudkip.png		  trubbish.png
# dwebble.png		  mudsdale.jpg		  trumbeak.jpg
# eelektrik.png		  muk.png		  tsareena.jpg
# eelektross.png		  munchlax.png		  turtonator.jpg
# eevee.png		  munna.png		  turtwig.png
# ekans.png		  murkrow.png		  tympole.png
# electabuzz.png		  musharna.png		  tynamo.png
# electivire.png		  naganadel.jpg		  type-null.jpg
# electrike.png		  natu.png		  typhlosion.png
# electrode.png		  necrozma.jpg		  tyranitar.png
# elekid.png		  nidoking.png		  tyrantrum.png
# elgyem.png		  nidoqueen.png		  tyrogue.png
# emboar.png		  nidoran-f.png		  tyrunt.png
# emolga.png		  nidoran-m.png		  umbreon.png
# empoleon.png		  nidorina.png		  unfezant.png
# entei.png		  nidorino.png		  unown.png
# escavalier.png		  nihilego.jpg		  ursaring.png
# espeon.png		  nincada.png		  uxie.png
# espurr.png		  ninetales.png		  vanillish.png
# excadrill.png		  ninjask.png		  vanillite.png
# exeggcute.png		  noctowl.png		  vanilluxe.png
# exeggutor.png		  noibat.png		  vaporeon.png
# exploud.png		  noivern.png		  venipede.png
# farfetchd.png		  nosepass.png		  venomoth.png
# fearow.png		  numel.png		  venonat.png
# feebas.png		  nuzleaf.png		  venusaur.png
# fennekin.png		  octillery.png		  vespiquen.png
# feraligatr.png		  oddish.png		  vibrava.png
# ferroseed.png		  omanyte.png		  victini.png
# ferrothorn.png		  omastar.png		  victreebel.png
# finneon.png		  onix.png		  vigoroth.png
# flaaffy.png		  oranguru.jpg		  vikavolt.jpg
# flabebe.png		  oricorio-baile.jpg	  vileplume.png
# flareon.png		  oshawott.png		  virizion.png
# fletchinder.png		  pachirisu.png		  vivillon.png
# fletchling.png		  palkia.png		  volbeat.png
# floatzel.png		  palossand.jpg		  volcanion.png
# floette.png		  palpitoad.png		  volcarona.png
# florges.png		  pancham.png		  voltorb.png
# flygon.png		  pangoro.png		  vullaby.png
# fomantis.jpg		  panpour.png		  vulpix.png
# foongus.png		  pansage.png		  wailmer.png
# forretress.png		  pansear.png		  wailord.png
# fraxure.png		  parasect.png		  walrein.png
# frillish.png		  paras.png		  wartortle.png
# froakie.png		  passimian.jpg		  watchog.png
# frogadier.png		  patrat.png		  weavile.png
# froslass.png		  pawniard.png		  weedle.png
# furfrou.png		  pelipper.png		  weepinbell.png
# furret.png		  persian.png		  weezing.png
# gabite.png		  petilil.png		  whimsicott.png
# gallade.png		  phanpy.png		  whirlipede.png
# galvantula.png		  phantump.png		  whiscash.png
# garbodor.png		  pheromosa.jpg		  whismur.png
# garchomp.png		  phione.png		  wigglytuff.png
# gardevoir.png		  pichu.png		  wimpod.jpg
# gastly.png		  pidgeot.png		  wingull.png
# gastrodon.png		  pidgeotto.png		  wishiwashi-solo.jpg
# genesect.png		  pidgey.png		  wobbuffet.png
# gengar.png		  pidove.png		  woobat.png
# geodude.png		  pignite.png		  wooper.png
# gible.png		  pikachu.png		  wormadam-plant.png
# gigalith.png		  pikipek.jpg		  wurmple.png
# girafarig.png		  piloswine.png		  wynaut.png
# giratina-altered.png	  pineco.png		  xatu.png
# glaceon.png		  pinsir.png		  xerneas.png
# glalie.png		  piplup.png		  xurkitree.jpg
# glameow.png		  plusle.png		  yamask.png
# gligar.png		  poipole.jpg		  yanma.png
# gliscor.png		  politoed.png		  yanmega.png
# gloom.png		  poliwag.png		  yungoos.jpg
# gogoat.png		  poliwhirl.png		  yveltal.png
# golbat.png		  poliwrath.png		  zangoose.png
# goldeen.png		  ponyta.png		  zapdos.png
# golduck.png		  poochyena.png		  zebstrika.png
# golem.png		  popplio.jpg		  zekrom.png
# golett.png		  porygon2.png		  zeraora.jpg
# golisopod.jpg		  porygon.png		  zigzagoon.png
# golurk.png		  porygon-z.png		  zoroark.png
# goodra.png		  primarina.jpg		  zorua.png
# goomy.png		  primeape.png		  zubat.png
# gorebyss.png		  prinplup.png		  zweilous.png
# gothita.png		  probopass.png		  zygarde-50.png
# gothitelle.png		  psyduck.png

# %%
# !ls images/images -1 | wc -l
# Out:
# 809

# %%
import pandas as pd
data = pd.read_csv('pokemon.csv')
data
# Out:
#             Name     Type1   Type2
# 0      bulbasaur     Grass  Poison
# 1        ivysaur     Grass  Poison
# 2       venusaur     Grass  Poison
# 3     charmander      Fire     NaN
# 4     charmeleon      Fire     NaN
# ..           ...       ...     ...
# 804    stakataka      Rock   Steel
# 805  blacephalon      Fire   Ghost
# 806      zeraora  Electric     NaN
# 807       meltan     Steel     NaN
# 808     melmetal     Steel     NaN
#
# [809 rows x 3 columns]

# %%
data.value_counts('Type1')
# Out:
# Type1
# Water       114
# Normal      105
# Grass        78
# Bug          72
# Fire         53
# Psychic      53
# Rock         46
# Electric     40
# Poison       34
# Ground       32
# Fighting     29
# Dark         29
# Ghost        27
# Dragon       27
# Steel        26
# Ice          23
# Fairy        18
# Flying        3
# dtype: int64

# %%
data = data[data.Type1.isin(['Water','Grass','Fire'])][['Name','Type1']]
data
# Out:
#             Name  Type1
# 0      bulbasaur  Grass
# 1        ivysaur  Grass
# 2       venusaur  Grass
# 3     charmander   Fire
# 4     charmeleon   Fire
# ..           ...    ...
# 778      bruxish  Water
# 786    tapu-bulu  Grass
# 787    tapu-fini  Water
# 797      kartana  Grass
# 805  blacephalon   Fire
#
# [245 rows x 2 columns]

# %%
print('Data shape',data.shape)
print('Number of unique names',data.Name.nunique())
# Out:
# Data shape (245, 2)
# Number of unique names 245

# %%
import os
import numpy as np
import pandas as pd
import cv2

image_df = []

path_start = 'images/images/'
for filename in os.listdir(path_start):
    if filename.endswith(".png"):
        image_name = filename.split('.')[0]

        image = cv2.imread(os.path.join(path_start, filename))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image_df.append({'Name':image_name,'img':np.array(image)})

image_df = pd.DataFrame(image_df)

data = data.merge(image_df, how='inner', on='Name')
data.img.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 218 entries, 0 to 217
# Series name: img
# Non-Null Count  Dtype
# --------------  -----
# 218 non-null    object
# dtypes: object(1)
# memory usage: 3.4+ KB

# %%
data.value_counts('Type1')
# Out:
# Type1
# Water    105
# Grass     66
# Fire      47
# dtype: int64

# %%
data.loc[0].img.shape
# Out:
# (120, 120, 3)

# %%
import matplotlib.pyplot as plt

for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(data.loc[i*5].img)
    plt.title(f"{data.loc[i*5].Name},{data.loc[i*5].Type1}")
    plt.axis('off')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

X = np.array(data['img'].tolist(), dtype = np.float32) / 255.0
y = data['Type1']

datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

augmented_images = []
augmented_labels = []

for i in range(len(X)):
    image = X[i]
    label = y[i]
    image = np.expand_dims(image, axis=0)
    label = np.array([label])
    augmented_images_batch, augmented_labels_batch = [], []
    j=0
    for x_batch, y_batch in datagen.flow(image, label, batch_size=4):
        augmented_images_batch.extend(x_batch)
        augmented_labels_batch.extend(y_batch)
        j+=1
        if j>3:
            break
    augmented_images.extend(augmented_images_batch)
    augmented_labels.extend(augmented_labels_batch)

augmented_images = np.array(augmented_images)
augmented_labels = np.array(augmented_labels)

print(X.shape)
print(augmented_images.shape)
# Out:
# (218, 120, 120, 3)
# (872, 120, 120, 3)

# %%
X = np.concatenate((X, augmented_images), axis=0)
y = np.concatenate((y,augmented_labels), axis=0)
print(X.shape)
# Out:
# (1090, 120, 120, 3)

# %%
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(augmented_images[i*10])
    plt.title(f"{augmented_labels[i*10]}")
    plt.axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

labels_dict = {'Water': 0, 'Grass': 1, 'Fire': 2}

y_final = []
for yi in y:
    y_final.append(labels_dict[yi])

X_train, X_test, y_train, y_test=train_test_split(X,y_final, test_size=.2)

X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Conv2D(filters = 32, 
                  kernel_size = (3, 3), 
                  activation = 'relu', 
                  input_shape = (120, 120, 3),
                  kernel_regularizer = tf.keras.regularizers.l2(l = 0.01)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(filters = 64, 
                  kernel_size = (3, 3), 
                  activation = 'relu', 
                  kernel_regularizer = tf.keras.regularizers.l2(l = 0.01)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(filters = 128, 
                  kernel_size = (3, 3), 
                  activation = 'relu', 
                  kernel_regularizer = tf.keras.regularizers.l2(l = 0.01)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(3, activation = 'softmax')
])
model.compile(optimizer = 'adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 118, 118, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 59, 59, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 59, 59, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 28, 28, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 13, 13, 128)       0
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2862659 (10.92 MB)
# Trainable params: 2862659 (10.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
histor = model.fit(X_train, y_train, epochs=20, validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 28/28 [==============================] - 8s 235ms/step - loss: 2.2178 - accuracy: 0.4289 - val_loss: 1.8407 - val_accuracy: 0.4725
# Epoch 2/20
# 28/28 [==============================] - 6s 231ms/step - loss: 1.6208 - accuracy: 0.4839 - val_loss: 1.3732 - val_accuracy: 0.4725
# Epoch 3/20
# 28/28 [==============================] - 6s 225ms/step - loss: 1.2158 - accuracy: 0.5837 - val_loss: 1.0460 - val_accuracy: 0.6330
# Epoch 4/20
# 28/28 [==============================] - 6s 225ms/step - loss: 0.9809 - accuracy: 0.6445 - val_loss: 0.9453 - val_accuracy: 0.6468
# Epoch 5/20
# 28/28 [==============================] - 6s 225ms/step - loss: 0.8385 - accuracy: 0.7122 - val_loss: 0.8471 - val_accuracy: 0.7064
# Epoch 6/20
# 28/28 [==============================] - 6s 227ms/step - loss: 0.7827 - accuracy: 0.7397 - val_loss: 0.8504 - val_accuracy: 0.7110
# Epoch 7/20
# 28/28 [==============================] - 6s 224ms/step - loss: 0.6633 - accuracy: 0.7844 - val_loss: 0.8278 - val_accuracy: 0.7110
# Epoch 8/20
# 28/28 [==============================] - 6s 224ms/step - loss: 0.5728 - accuracy: 0.8372 - val_loss: 0.7281 - val_accuracy: 0.7936
# Epoch 9/20
# 28/28 [==============================] - 6s 224ms/step - loss: 0.5033 - accuracy: 0.8624 - val_loss: 0.6823 - val_accuracy: 0.8073
# Epoch 10/20
# 28/28 [==============================] - 6s 227ms/step - loss: 0.4981 - accuracy: 0.8532 - val_loss: 0.6876 - val_accuracy: 0.7936
# Epoch 11/20
# 28/28 [==============================] - 6s 225ms/step - loss: 0.4699 - accuracy: 0.8704 - val_loss: 0.6659 - val_accuracy: 0.8028
# Epoch 12/20
# 28/28 [==============================] - 6s 224ms/step - loss: 0.4051 - accuracy: 0.8842 - val_loss: 0.7112 - val_accuracy: 0.7752
# Epoch 13/20
# 28/28 [==============================] - 6s 229ms/step - loss: 0.4205 - accuracy: 0.8761 - val_loss: 0.6820 - val_accuracy: 0.8165
# Epoch 14/20
# 28/28 [==============================] - 6s 224ms/step - loss: 0.3847 - accuracy: 0.8888 - val_loss: 0.6772 - val_accuracy: 0.7798
# Epoch 15/20
# 28/28 [==============================] - 6s 225ms/step - loss: 0.3604 - accuracy: 0.8968 - val_loss: 0.6858 - val_accuracy: 0.7890
# Epoch 16/20
# 28/28 [==============================] - 6s 224ms/step - loss: 0.3062 - accuracy: 0.9174 - val_loss: 0.8083 - val_accuracy: 0.7706
# Epoch 17/20
# 28/28 [==============================] - 6s 227ms/step - loss: 0.2796 - accuracy: 0.9312 - val_loss: 0.7801 - val_accuracy: 0.8073
# Epoch 18/20
# 28/28 [==============================] - 6s 232ms/step - loss: 0.3077 - accuracy: 0.9243 - val_loss: 0.7514 - val_accuracy: 0.7982
# Epoch 19/20
# 28/28 [==============================] - 6s 225ms/step - loss: 0.2659 - accuracy: 0.9312 - val_loss: 0.8739 - val_accuracy: 0.7798
# Epoch 20/20
# 28/28 [==============================] - 6s 227ms/step - loss: 0.2387 - accuracy: 0.9564 - val_loss: 1.0291 - val_accuracy: 0.8028

# %%
plt.plot(histor.history['accuracy'])
plt.plot(histor.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])

# %%
y_pred = np.argmax(model.predict(X_test),axis=1)
# Out:
# 7/7 [==============================] - 0s 53ms/step

# %%
from tensorflow.keras.preprocessing import image

img = image.load_img('./images/images/bulbasaur.png', target_size=(120, 120, 3))
img
# Out:
# <PIL.Image.Image image mode=RGB size=120x120>

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
print(preds)
# Out:
# [[1. 0. 0.]]

# %%
if (preds[0][0]>0):
  print("Water")
if (preds[0][1]>0):
  print("Grass")
if (preds[0][2]>0):
  print("Fire")
# Out:
# Water

# %% [markdown]
# Классификацая изображения. Всего  3 класса: Water, Grass, Fire
